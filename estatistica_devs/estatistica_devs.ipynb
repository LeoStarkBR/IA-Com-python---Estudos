# %%
import pandas as pd

# %% [markdown]
# dict seria como um dicionario de dados, temos algo da seguinte forma:

# %%
dict_medidas = {'idade': [15, 18, 25, 25, 40, 55,58,60, 80], 'altura': [160, 162, 165, 168, 172, 174, 174, 174, 176]}

# %% [markdown]
# Um DataFrame é uma estrutura de dados tabular bidimensional usada pelo pandas. Ele é semelhante a uma planilha ou tabela SQL, com linhas e colunas, e é amplamente utilizado para manipulação e análise de dados em Python.

# %%
df_medidas = pd.DataFrame.from_dict(dict_medidas)

# %%
df_medidas
# Out:
#    idade  altura
# 0     15     160
# 1     18     162
# 2     25     165
# 3     25     168
# 4     40     172
# 5     55     174
# 6     58     174
# 7     60     174
# 8     80     176

# %% [markdown]
# Transformando um Dicionário em um DataFrame
#
# No pandas, você pode criar um DataFrame a partir de um dicionário de dados. Para isso, usamos o método pd.DataFrame.from_dict().
# 	•	Dicionário: Contém os dados organizados em pares de chave-valor.
# 	•	As chaves representam os nomes das colunas ou dos índices.
# 	•	Os valores associados podem ser listas ou arrays que contêm os dados de cada coluna.

# %% [markdown]
# 1. Introdução às Medidas Estatísticas
#
# As medidas de tendência central são usadas para resumir um conjunto de dados com um único valor que representa o “centro” ou o ponto mais típico dos dados. As mais comuns são:
# 	1.	Média: A soma de todos os valores dividida pelo número de observações.
# 	2.	Mediana: O valor central de um conjunto de dados ordenado.
# 	3.	Moda: O valor que mais se repete no conjunto de dados.

# %%
#media
df_medidas["idade"].mean()
# Out:
# np.float64(41.77777777777778)

# %%
#mediana
df_medidas["idade"].median()
# Out:
# np.float64(40.0)

# %%
#moda ou valor mais frequente dentrdo deste conjunto de dados
df_medidas["idade"].mode()
# Out:
# 0    25
# Name: idade, dtype: int64

# %%
#vamos testar com altura
df_medidas["altura"].mean()
# Out:
# np.float64(169.44444444444446)

# %%
df_medidas["altura"].median()
# Out:
# np.float64(172.0)

# %%
df_medidas["altura"].mode()
# Out:
# 0    174
# Name: altura, dtype: int64

# %% [markdown]
# ### Medidas de dispersão

# %% [markdown]
# Medidas de Dispersão
# 	1.	Variância
# 	•	Mede o grau de dispersão dos dados em relação à média.
# 	•	Calculada como a média dos quadrados das diferenças entre cada valor e a média.
# 	•	Fórmula:
#
# $$
# \text{Variância} = \frac{\sum (x_i - \bar{x})^2}{n}
# $$
#
# 	2.	Desvio Padrão
# 	•	É a raiz quadrada da variância.
# 	•	Indica a dispersão na mesma unidade dos dados originais.
# 	•	Fórmula:
#
# $$
# \text{Desvio Padrão} = \sqrt{\text{Variância}}
# $$
#
# 	3.	Coeficiente de Variação (CV)
# 	•	Mede a variabilidade relativa em relação à média, expressa em percentual.
# 	•	Útil para comparar dispersões de diferentes conjuntos de dados.
# 	•	Fórmula:
#
# $$
# CV = \frac{\text{Desvio Padrão}}{\text{Média}} \times 100\%
# $$

# %%
# Variancia
df_medidas["idade"].var()
# Out:
# np.float64(509.94444444444446)

# %%
# Desvio padrão
df_medidas["idade"].std()
# Out:
# np.float64(22.58194952709895)

# %%
#coeficiente de variação
df_medidas["idade"].std() / df_medidas["idade"].mean() * 100
# Out:
# np.float64(54.05253876167302)

# %% [markdown]
# Neste ultimo podemos notar que podemos fazer a formula dentro do codigo, não fazendo conforme os demais outros.

# %%
# coeficente de variacao da altura
df_medidas["altura"].std() / df_medidas["altura"].mean() * 100
# Out:
# np.float64(3.4803552812368785)

# %% [markdown]
# Chegamos a conclusao que o cojunto de dados de idade tem uma variacao muito maior que a variacao da altura.

# %% [markdown]
# ### Medidas de Forma

# %% [markdown]
# Medidas de Forma
# 	1.	Assimetria (Skewness)
# 	•	Mede a simetria da distribuição dos dados em relação à média.
# 	•	Interpretação:
# 	•	Assimetria positiva: cauda da distribuição mais longa à direita.
# 	•	Assimetria negativa: cauda da distribuição mais longa à esquerda.
# 	•	Assimetria zero: distribuição simétrica.
# 	•	Fórmula Geral:
#
# $$
# \text{Assimetria} = \frac{\frac{1}{n} \sum (x_i - \bar{x})^3}{s^3}
# $$
#
# Onde s é o desvio padrão.
#
# Curtose (Kurtosis)
# 	•	Mede o grau de achatamento ou pontualidade da distribuição em relação a uma distribuição normal.
# 	•	Interpretação:
# 	•	Curtose > 3: distribuição mais pontiaguda (leptocúrtica).
# 	•	Curtose < 3: distribuição mais achatada (platicúrtica).
# 	•	Curtose = 3: distribuição normal (mesocúrtica).
# 	•	Fórmula Geral:
#
# $$
# \text{Curtose} = \frac{\frac{1}{n} \sum (x_i - \bar{x})^4}{s^4}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Assimetria - Idade
df_medidas["idade"].skew()
# Out:
# np.float64(0.368108517895537)

# %%
#Assimetria - Altura
df_medidas["altura"].skew()
# Out:
# np.float64(-0.598486996170113)

# %%
# Curtose - Idade
df_medidas["idade"].kurt()
# Out:
# np.float64(-1.1344461075421046)

# %%
# Curtose - Altura
df_medidas["altura"].kurt()
# Out:
# np.float64(-1.3372641199913002)

# %% [markdown]
# Interpretação dos Dados
# 1. Assimetria - Idade
# Valor: 0.368
# - Distribuição ligeiramente assimétrica à direita (positiva).
# - Indica que a maioria das idades está concentrada à esquerda da média, mas há valores maiores espalhados à direita.
# 2. Assimetria - Altura
# Valor: -0.599
# - Distribuição moderadamente assimétrica à esquerda (negativa).
# - A maioria das alturas está concentrada à direita da média, mas há valores menores espalhados à esquerda.
# 3. Curtose - Idade
# Valor: -1.134
# - Curtose negativa indica uma distribuição mais achatada (platicúrtica) em comparação com a normal.
# 4. Curtose - Altura
# Valor: -1.337
# - Também apresenta uma distribuição achatada, com menor concentração de valores próximos da média.

# %%
# Obter medidas estatisticas, podemos gerar um resumo dos dados analisados
df_medidas.idade.describe()
# Out:
# count     9.000000
# mean     41.777778
# std      22.581950
# min      15.000000
# 25%      25.000000
# 50%      40.000000
# 75%      58.000000
# max      80.000000
# Name: idade, dtype: float64

# %% [markdown]
# ### Correlacão

# %% [markdown]
# O que é correlação?
#
# Na estatística, a correlação mede a relação entre duas variáveis. Ela indica:
# - Correlação positiva: Quando uma variável aumenta, a outra também tende a aumentar (ex.: altura e peso).
# - Correlação negativa: Quando uma variável aumenta, a outra tende a diminuir (ex.: temperatura e uso de aquecedores).
# - Sem correlação: Quando as variáveis não têm relação linear (ex.: cor dos olhos e altura).
#
# Por que a correlação é importante em Machine Learning?
# 1. Identificar padrões nos dados:
# - A correlação ajuda a entender quais variáveis têm uma relação importante. Por exemplo, se a renda está correlacionada com o nível de escolaridade.
# 2. Selecionar características relevantes:
# - Variáveis com alta correlação podem ser mais relevantes para o modelo, enquanto variáveis sem correlação podem ser descartadas, reduzindo a complexidade do modelo.
# 3. Melhorar a precisão:
# - Compreendendo as relações entre variáveis, os modelos podem fazer previsões mais precisas.
# 4. Ajustar os modelos:
# - Ao observar correlações, podemos ajustar os modelos para melhor refletir as relações nos dados e evitar erros como a inclusão de variáveis irrelevantes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# O que é Correlação?
#
# Correlação é uma forma de medir o quanto duas variáveis estão relacionadas. Ela responde:
# - “Se uma variável muda, o que acontece com a outra?”
# - Pode ser positiva (as duas crescem juntas), negativa (uma cresce enquanto a outra diminui) ou nula (sem relação).
#
# Agora, vamos entender as duas formas mais comuns de calcular a correlação: Pearson e Spearman.

# %% [markdown]
# 1. Coeficiente de Pearson
#
# Quando usar:
# - Para relações lineares (quando os dados seguem uma linha reta, mais ou menos).
# - Funciona bem com variáveis numéricas (ex.: altura e peso).
#
# Como funciona:
# - Pearson mede o grau de alinhamento linear entre duas variáveis.
# - Ele varia entre:
# - +1: relação linear positiva perfeita (quando uma aumenta, a outra também aumenta proporcionalmente).
# - -1: relação linear negativa perfeita (quando uma aumenta, a outra diminui proporcionalmente).
# - 0: não há relação linear.
#
# Exemplo prático:
# - Altura e peso: se pessoas mais altas geralmente pesam mais, você terá uma correlação positiva.
#
# 2. Coeficiente de Spearman
#
# Quando usar:
# - Para relações monotônicas, que não precisam ser lineares (os dados só precisam crescer ou decrescer de forma consistente).
# - Útil quando os dados:
# - Não têm uma relação clara.
# - São ordinais ou não numéricos escalonáveis (ex.: classificações como “bom”, “médio”, “ruim”).
#
# Como funciona:
# - Spearman classifica os dados em ordem e mede a correlação entre as posições (ranks).
# - Também varia de:
# - +1: relação monotônica positiva perfeita.
# - -1: relação monotônica negativa perfeita.
# - 0: sem relação monotônica.
#
# Exemplo prático:
# - Notas de uma prova e horas de estudo: mesmo que não seja linear, mais horas de estudo geralmente levam a notas melhores.
#
# Resumo: Como Escolher?
# 1. Use Pearson:
# - Quando espera uma relação linear entre variáveis numéricas.
# 2. Use Spearman:
# - Quando não há uma relação linear clara ou os dados são ordinais ou pouco escalonáveis.

# %%
df_medidas.corr(method='pearson')
#nao precisamos definir a variavel, pois o metodo corr ja faz isso e temos apenas duas variaveis
# Out:
#            idade    altura
# idade   1.000000  0.931024
# altura  0.931024  1.000000

# %% [markdown]
# Podemos concluir que existe uma correlação entre a idade e a altura, indicando que, à medida que a idade aumenta, a altura também tende a aumentar até certo ponto. Esse comportamento sugere uma relação positiva.

# %%
#correlacao com o Spearman
df_medidas.corr(method='spearman')
# Out:
#            idade    altura
# idade   1.000000  0.978803
# altura  0.978803  1.000000

# %% [markdown]
# Mostra que tem uma associacão positiva entre as duas variaveis.

# %% [markdown]
# ### Representacão Graficas

# %% [markdown]
# Histograma - É usado para variáveis numéricas contínuas, mostrando a distribuição dos dados em intervalos.
# Gráfico de Barras - Aplicável a variáveis categóricas ou discretas, exibindo a contagem ou frequência de cada categoria.
# Gráfico de Dispersão - Usado para mostrar a relação entre duas variáveis numéricas, ajudando a identificar padrões ou
# tendências.
# Box Plot (Diagrama de Caixa) - Adequado para variáveis numéricas ou categóricas ordinais, revelando distribuição, mediana e valores
# atípicos.
# Gráfico de Linhas - Utilizado para variáveis numéricas ao longo do tempo ou em uma sequência, destacando tendências
# temporais.

# %%
#Histograma da Idade
df_medidas.idade.hist()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
#histograma da altura
df_medidas.altura.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Graficos de Barras - DataFrame de vendas

# %%
#Vamos criar um novo DataFrame para podermos usar esse meotodo plot
dict_vendas = {'Categoria': ['masculino', 'feminino', 'infantil', 'casa'], 'valor': [400000, 600000, 250000, 580000], 'quantidade': [3000, 5000, 1500, 2500]}

# %%
df_vendas = pd.DataFrame.from_dict(dict_vendas)

# %%
df_vendas
# Out:
#    Categoria   valor  quantidade
# 0  masculino   40000        3000
# 1   feminino  600000        5000
# 2   infantil  250000        1500
# 3       casa  580000        2500

# %%
#gaficos de barras verticais - valor
df_vendas.plot.bar(x='Categoria', y='valor')
# Out:
# <Axes: xlabel='Categoria'>

# %%
#Graficos de Barras verticais - valor (ordenado)
df_vendas.sort_values(by='valor', ascending=False).plot.bar(x='Categoria', y='valor')
# Out:
# <Axes: xlabel='Categoria'>
